# %%
# !sudo apt install tesseract-ocr
# !sudo apt-get install poppler-utils
# !pip install zero-shot-re neo4j
# !pip install pdf2image
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 18 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (4,683 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.2 [186 kB]
# Fetched 186 kB in 0s (379 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package poppler-utils.
# (Reading database ... 120942 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.2_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.2) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting zero-shot-re
#   Downloading zero_shot_re-0.0.4-py3-none-any.whl (6.6 kB)
# Collecting neo4j
#   Downloading neo4j-5.13.0.tar.gz (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.3/192.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy==1.19.1 (from zero-shot-re)
#   Downloading numpy-1.19.1.zip (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 116.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting pdf2image
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pdf2image) (9.4.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.3
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
import requests
import pdf2image
import pytesseract

pdf = requests.get('https://arxiv.org/pdf/2110.03526.pdf')
doc = pdf2image.convert_from_bytes(pdf.content)

# Get the article text
article = []
for page_number, page_data in enumerate(doc):
    txt = pytesseract.image_to_string(page_data).encode("utf-8")
    # Sixth page are only references
    if page_number < 6:
      article.append(txt.decode("utf-8"))
article_txt = " ".join(article)

# %%
import nltk
nltk.download('punkt')

def clean_text(text):
  """Remove section titles and figure descriptions from text"""
  clean = "\n".join([row for row in text.split("\n") if (len(row.split(" "))) > 3 and not (row.startswith("(a)"))
                    and not row.startswith("Figure")])
  return clean

text = article_txt.split("INTRODUCTION")[1]
ctext = clean_text(text)
sentences = nltk.tokenize.sent_tokenize(ctext)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import hashlib
import json
headers = {
  'Content-Type': 'application/json'
}

def query_raw(text, url="http://bern2.korea.ac.kr/plain"):
  """Biomedical entity linking API"""
  resp = requests.post(url, data=json.dumps({'text': text}), headers=headers)
  print(resp.text)
  return resp.json()

entity_list = []
# The last sentence is invalid
for s in sentences[:-1]:
  entity_list.append(query_raw(s))

parsed_entities = []
for entities in entity_list:
  e = []
  # If there are not entities in the text
  if not entities.get('annotations'):
    parsed_entities.append({'text':entities['text'], 'text_sha256': hashlib.sha256(entities['text'].encode('utf-8')).hexdigest()})
    continue
  for entity in entities['annotations']:
    other_ids = [id for id in entity['id'] if not id.startswith("BERN")]
    entity_type = entity['obj']
    entity_name = entities['text'][entity['span']['begin']:entity['span']['end']]
    try:
      entity_id = [id for id in entity['id'] if id.startswith("BERN")][0]
    except IndexError:
      entity_id = entity_name
    e.append({'entity_id': entity_id, 'other_ids': other_ids, 'entity_type': entity_type, 'entity': entity_name})
  parsed_entities.append({'entities':e, 'text':entities['text'], 'text_sha256': hashlib.sha256(entities['text'].encode('utf-8')).hexdigest()})
# Out:
# {"annotations": [{"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "people", "obj": "species", "prob": 0.9871211647987366, "span": {"begin": 5, "end": 11}}, {"id": ["mesh:D012871"], "is_neural_normalized": false, "mention": "skin diseases", "obj": "disease", "prob": 0.9991875886917114, "span": {"begin": 17, "end": 30}}, {"id": ["mesh:D002908"], "is_neural_normalized": true, "mention": "chronic wounds", "obj": "disease", "prob": 0.9991545081138611, "span": {"begin": 39, "end": 53}}, {"id": ["mesh:D003668"], "is_neural_normalized": true, "mention": "non-healing and diabetic ulcers", "obj": "disease", "prob": 0.9781932234764099, "span": {"begin": 55, "end": 86}}], "text": "Many people with skin diseases such as chronic wounds, non-healing and diabetic ulcers need reconstruction and regeneration of their skin.", "timestamp": "Fri Sep 29 11:04:19 +0000 2023"}
# {"annotations": [{"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "people", "obj": "species", "prob": 0.958552896976471, "span": {"begin": 135, "end": 141}}], "text": "In addition, the medical industry also needed a method of skin rejuvenation and reconstruction for cosmetic purposes, even for healthy people.", "timestamp": "Fri Sep 29 11:04:20 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "pluripotent", "obj": "cell_line", "prob": 0.5138478875160217, "span": {"begin": 51, "end": 62}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "pluripotent stem cells", "obj": "cell_type", "prob": 0.787431001663208, "span": {"begin": 51, "end": 73}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "bone marrow stem cells", "obj": "cell_type", "prob": 0.8902274370193481, "span": {"begin": 116, "end": 138}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fat-derived stem cells", "obj": "cell_type", "prob": 0.8447101712226868, "span": {"begin": 140, "end": 162}}], "text": "Reconstructive medicine used the method to deliver pluripotent stem cells to the 33 years after the introduction of bone marrow stem cells, fat-derived stem cells have become an excellent source for cell therapy.", "timestamp": "Fri Sep 29 11:04:21 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem cells", "obj": "cell_type", "prob": 0.8689588904380798, "span": {"begin": 50, "end": 60}}], "text": "In 1961, two Canadian scientists first introduced stem cells.", "timestamp": "Fri Sep 29 11:04:22 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "hematopoietic stem cells", "obj": "cell_type", "prob": 0.8947269320487976, "span": {"begin": 31, "end": 55}}, {"id": ["mesh:D007938"], "is_neural_normalized": false, "mention": "leukemia", "obj": "disease", "prob": 0.9999961853027344, "span": {"begin": 94, "end": 102}}, {"id": ["mesh:D001327", "mim:109100"], "is_neural_normalized": false, "mention": "autoimmune diseases", "obj": "disease", "prob": 0.999987781047821, "span": {"begin": 119, "end": 138}}], "text": "These cells, later found to be hematopoietic stem cells, have been used successfully to treat leukemia and some severe autoimmune diseases called bone marrow transplants.", "timestamp": "Fri Sep 29 11:04:23 +0000 2023"}
# {"annotations": [{"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8483867645263672, "span": {"begin": 17, "end": 26}}, {"id": ["mim:140600", "mesh:D010003"], "is_neural_normalized": false, "mention": "joint diseases", "obj": "disease", "prob": 0.9898857474327087, "span": {"begin": 186, "end": 200}}], "text": "In 1968, another stem cell was introduced into the bone marrow, which has been shown to be effective due to its high ability to regulate immunity in many diseases, including skin, bone, joint diseases, heart, brain, nerves, and kidney.", "timestamp": "Fri Sep 29 11:04:24 +0000 2023"}
# {"annotations": [{"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "human", "obj": "species", "prob": 0.9944596290588379, "span": {"begin": 67, "end": 72}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.7876850366592407, "span": {"begin": 99, "end": 108}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "bone marrow stem cells", "obj": "cell_type", "prob": 0.8813543915748596, "span": {"begin": 121, "end": 143}}], "text": "Nevertheless, it took scientists another 33 years to discover that human adipose tissue also has a stem cell, similar to bone marrow stem cells.", "timestamp": "Fri Sep 29 11:04:25 +0000 2023"}
# {"annotations": [{"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "human", "obj": "species", "prob": 0.9912093877792358, "span": {"begin": 13, "end": 18}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem cells", "obj": "cell_type", "prob": 0.8396767377853394, "span": {"begin": 49, "end": 59}}], "text": "Each gram of human fat has 100 to 500 times more stem cells than bone marrow and is easier to obtain.", "timestamp": "Fri Sep 29 11:04:26 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "bone marrow stem cells", "obj": "cell_type", "prob": 0.8806788921356201, "span": {"begin": 34, "end": 56}}], "text": "Although there are differences in bone marrow stem cells and fat, these advantages have attracted the attention of many researchers.", "timestamp": "Fri Sep 29 11:04:27 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Mesenchymal stem cells", "obj": "cell_type", "prob": 0.9098013043403625, "span": {"begin": 0, "end": 22}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "targeted", "obj": "cell_line", "prob": 0.7251231670379639, "span": {"begin": 203, "end": 211}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "targeted tissue", "obj": "cell_type", "prob": 0.5698448419570923, "span": {"begin": 203, "end": 218}}], "text": "Mesenchymal stem cells are the most interesting because when they get placed in the right environment and are coupled with the proper growth factors, they can choose a pathway to differentiate into that targeted tissue.", "timestamp": "Fri Sep 29 11:04:28 +0000 2023"}
# {"annotations": [], "text": "Also, they are very accessible, inexpensive, easy to extract, and reproducible.", "timestamp": "Fri Sep 29 11:04:29 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_type", "prob": 0.901149570941925, "span": {"begin": 21, "end": 43}}], "text": "The sources of these mesenchymal stem cells are bone marrow, bone, connective tissues, fats, etc.", "timestamp": "Fri Sep 29 11:04:31 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.9080085158348083, "span": {"begin": 57, "end": 74}}], "text": "The best reservoir that has recently been discovered for mesenchymal cells is fat.", "timestamp": "Fri Sep 29 11:04:31 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9962303042411804, "span": {"begin": 30, "end": 38}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.899080216884613, "span": {"begin": 51, "end": 62}}], "text": "Fats are made out of fibrous, collagen fibers, and fibroblasts.", "timestamp": "Fri Sep 29 11:04:33 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:4312"], "is_neural_normalized": true, "mention": "collagenase enzymes", "obj": "gene", "prob": 0.893478512763977, "span": {"begin": 26, "end": 45}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9891467094421387, "span": {"begin": 68, "end": 76}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.8481180667877197, "span": {"begin": 88, "end": 99}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_line", "prob": 0.8712296485900879, "span": {"begin": 130, "end": 152}}], "text": "On one hand, by injecting collagenase enzymes into the fat, all the collagen fibers and fibroblasts would slip away, and the pure mesenchymal stem cells would be available.", "timestamp": "Fri Sep 29 11:04:35 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "engineered stem cell", "obj": "cell_line", "prob": 0.7071548104286194, "span": {"begin": 26, "end": 46}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "SVF", "obj": "cell_line", "prob": 0.7257594466209412, "span": {"begin": 66, "end": 69}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.4765108823776245, "span": {"begin": 101, "end": 118}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "inflammatory cells", "obj": "cell_type", "prob": 0.8456407189369202, "span": {"begin": 136, "end": 154}}, {"id": ["CL:0000235"], "is_neural_normalized": false, "mention": "macrophage", "obj": "cell_type", "prob": 0.8159772157669067, "span": {"begin": 160, "end": 170}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "-monocyte", "obj": "cell_type", "prob": 0.6472268104553223, "span": {"begin": 170, "end": 179}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.4470183253288269, "span": {"begin": 184, "end": 195}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.8758742809295654, "span": {"begin": 201, "end": 218}}], "text": "On the other hand, In the engineered stem cell vascular fraction (SVF), which is a pellet containing mesenchymal cells, growth factors, inflammatory cells like macrophage-monocyte and fibroblasts, the mesenchymal cells get separated from all the other components by the centrifugation process.", "timestamp": "Fri Sep 29 11:04:36 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_line", "prob": 0.8412234783172607, "span": {"begin": 12, "end": 34}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.5326942205429077, "span": {"begin": 117, "end": 128}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9679531455039978, "span": {"begin": 133, "end": 141}}], "text": "Placing the mesenchymal stem cells into the targeted environment and providing the proper growth factors can produce fibroblasts and collagen to reconstruct the skin.", "timestamp": "Fri Sep 29 11:04:37 +0000 2023"}
# {"annotations": [{"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.841631293296814, "span": {"begin": 24, "end": 33}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem", "obj": "cell_line", "prob": 0.4844077527523041, "span": {"begin": 89, "end": 93}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8730692267417908, "span": {"begin": 89, "end": 98}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8665419816970825, "span": {"begin": 155, "end": 164}}], "text": "As mentioned above, the stem cell environment is critical, and there is a possibility of stem cell movement due to the blood flow and paracrine, which the stem cell would secrete and affect its environment.", "timestamp": "Fri Sep 29 11:04:38 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem", "obj": "cell_line", "prob": 0.5044615864753723, "span": {"begin": 37, "end": 41}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.848247230052948, "span": {"begin": 37, "end": 46}}], "text": "Therefore, the matrix that keeps the stem cell in its place from getting flushed away by the blood flow and affecting its environment, known as the scaffold, was discovered.", "timestamp": "Fri Sep 29 11:04:39 +0000 2023"}
# {"annotations": [], "text": "The scaffold has to have specific characteristics that would avoid a foreign body reaction; It could not be antigenic ,allergic, or infectious.", "timestamp": "Fri Sep 29 11:04:40 +0000 2023"}
# {"annotations": [], "text": "Additionally, it needed to be accessible and cheap to produce.", "timestamp": "Fri Sep 29 11:04:42 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.8845252990722656, "span": {"begin": 77, "end": 94}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "targeted", "obj": "cell_type", "prob": 0.5337246656417847, "span": {"begin": 138, "end": 146}}, {"id": ["NCBIGene:960"], "is_neural_normalized": true, "mention": "CD44 receptors", "obj": "gene", "prob": 0.9905749559402466, "span": {"begin": 181, "end": 195}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.7792468667030334, "span": {"begin": 210, "end": 221}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9915459752082825, "span": {"begin": 241, "end": 249}}], "text": "The newest method utilized has been using alginate scaffolds, containing the mesenchymal cells and the essential growth factors, into the targeted cell resulting in stimulating the CD44 receptors on the skin's fibroblasts, causing a rush of collagen production.", "timestamp": "Fri Sep 29 11:04:43 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:2141"], "is_neural_normalized": true, "mention": "green", "obj": "gene", "prob": 0.7219763398170471, "span": {"begin": 35, "end": 40}}, {"id": ["NCBITaxon:10095"], "is_neural_normalized": false, "mention": "mice", "obj": "species", "prob": 0.929449200630188, "span": {"begin": 122, "end": 126}}, {"id": ["NCBITaxon:10090"], "is_neural_normalized": false, "mention": "mouse", "obj": "species", "prob": 0.9631985425949097, "span": {"begin": 218, "end": 223}}], "text": "As we learned in our lectures, the green fluorescent protein bone marrow was implanted into non-green fluorescent protein mice resulting from HCT, (hematopoietic cell transplantation) improved the animal survival in a mouse model, which was surprising.", "timestamp": "Fri Sep 29 11:04:45 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem cells", "obj": "cell_type", "prob": 0.8490715026855469, "span": {"begin": 87, "end": 97}}], "text": "In this paper, the tissue regeneration of skin and the probability of hair growth from stem cells are being investigated.", "timestamp": "Fri Sep 29 11:04:46 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "skin cells", "obj": "cell_type", "prob": 0.7952063083648682, "span": {"begin": 100, "end": 110}}, {"id": ["mesh:D014947"], "is_neural_normalized": true, "mention": "skin wounds", "obj": "disease", "prob": 0.9994838237762451, "span": {"begin": 193, "end": 204}}], "text": "Over time, The biological skin replacement has dramatically improved from individual application of skin cells to cells and scaffold combinations for treatments, healing, and acute and chronic skin wounds.", "timestamp": "Fri Sep 29 11:04:47 +0000 2023"}
# {"annotations": [{"id": ["mesh:D002056"], "is_neural_normalized": false, "mention": "burns", "obj": "disease", "prob": 0.9995332956314087, "span": {"begin": 158, "end": 163}}], "text": "Permanent skin substitutes with cellular engineering combination has shown to have crucial wound closure of more than 90% of the total body surface region in burns [7].", "timestamp": "Fri Sep 29 11:04:48 +0000 2023"}
# {"annotations": [{"id": ["mesh:D014947"], "is_neural_normalized": true, "mention": "acute and chronic wounds", "obj": "disease", "prob": 0.9769277572631836, "span": {"begin": 47, "end": 71}}], "text": "As an advantage the morbidity and mortality of acute and chronic wounds have brought lower; However, yet they have been unable to eliminate all skin mechanisms and functions [7].", "timestamp": "Fri Sep 29 11:04:49 +0000 2023"}
# {"annotations": [{"id": ["mesh:D017496"], "is_neural_normalized": false, "mention": "Hypopigmentation", "obj": "disease", "prob": 0.9999969005584717, "span": {"begin": 11, "end": 27}}], "text": "Therefore, Hypopigmentation, the absence of lymphatic networks and stable vascular, hair follicles, sweat glands, adipose, and inadequate innervation are some of the missing elements of cellular or biological skin replacements equation [7].", "timestamp": "Fri Sep 29 11:04:50 +0000 2023"}
# {"annotations": [], "text": "The complete restoration of the anatomy and physiology of uninjured skin is highly dependent on the modulation of biological pathways of embryonic and fetal formation.", "timestamp": "Fri Sep 29 11:04:51 +0000 2023"}
# {"annotations": [{"id": ["mesh:D014947"], "is_neural_normalized": true, "mention": "skin wounds", "obj": "disease", "prob": 0.9995114207267761, "span": {"begin": 155, "end": 166}}, {"id": ["mesh:D002921"], "is_neural_normalized": false, "mention": "scarring", "obj": "disease", "prob": 0.8079688549041748, "span": {"begin": 413, "end": 421}}, {"id": ["mesh:D002056"], "is_neural_normalized": false, "mention": "burn", "obj": "disease", "prob": 0.9949151277542114, "span": {"begin": 463, "end": 467}}], "text": "developmental biology into possible biological skin replacements can have a full recovery of anatomy and physiology, along with eliminating morbidity from skin wounds In recent years, improvements in early wound excision, respiratory assistance, fluid revival, treatment of inhalation damage, enhanced immune function, infection prevention, integration of aerobic activity during healing, and advancement of anti-scarring techniques have all been accomplished in burn care.", "timestamp": "Fri Sep 29 11:04:53 +0000 2023"}
# {"annotations": [], "text": "These advancements also resulted in substantial decreases in death, hospitalization, and long-term morbidity.", "timestamp": "Fri Sep 29 11:04:54 +0000 2023"}
# {"annotations": [], "text": "Many strategies for healing deep partial and full-thickness burns have been developed by researchers, including the placement of the epidermal barrier through autologous or allogeneic transplantation.", "timestamp": "Fri Sep 29 11:04:55 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Autologous", "obj": "cell_line", "prob": 0.5263460278511047, "span": {"begin": 0, "end": 10}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Autologous cells", "obj": "cell_type", "prob": 0.871029257774353, "span": {"begin": 0, "end": 16}}], "text": "Autologous cells can permanently reside on the wound to have definitive wound closure.", "timestamp": "Fri Sep 29 11:04:56 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "allogeneic cells", "obj": "cell_type", "prob": 0.5603373050689697, "span": {"begin": 13, "end": 29}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "allogeneic fibroblast", "obj": "cell_type", "prob": 0.8816918134689331, "span": {"begin": 109, "end": 130}}], "text": "In contrast, allogeneic cells can stay on the wound for a few days or weeks; However, the combination of the allogeneic fibroblast with biodegradable scaffolds would provide extracellular matrix and growth factors components would facilitates faster wound closure by motivating autologous healing, but it does not last long maybe for only a few days to weeks.", "timestamp": "Fri Sep 29 11:04:57 +0000 2023"}
# {"annotations": [{"id": ["mesh:D002056"], "is_neural_normalized": false, "mention": "burns", "obj": "disease", "prob": 0.9859537482261658, "span": {"begin": 62, "end": 67}}], "text": "Although these methods do tend to decrease mortality in major burns, after transplantation, they neglect hair follicles and glands.", "timestamp": "Fri Sep 29 11:04:58 +0000 2023"}
# {"annotations": [], "text": "Scientists use techniques which can damage cells such as multi-layering of a variety of cells and the transition of cell-matrix droplets onto a substrate known as \"ink-jet printing,\" by amplifying a laser pulse.", "timestamp": "Fri Sep 29 11:04:59 +0000 2023"}
# {"annotations": [], "text": "The brief exposures to high pressure, temperature, or biochemical toxins would damage the cells [7].", "timestamp": "Fri Sep 29 11:05:00 +0000 2023"}
# {"annotations": [], "text": "autologous engineered skin substitutes.", "timestamp": "Fri Sep 29 11:05:01 +0000 2023"}
# {"annotations": [], "text": "Regenerative medicine is meant to restore the functionality of a harmed,   malfunctioning, or absent tissue.", "timestamp": "Fri Sep 29 11:05:02 +0000 2023"}
# {"annotations": [], "text": "In regenerative medicine, there are three primary methods.", "timestamp": "Fri Sep 29 11:05:03 +0000 2023"}
# {"annotations": [], "text": "Cell-based therapies are the first approach executed by the cells that are delivered to either directly regenerate a tissue or through the paracrine functions.", "timestamp": "Fri Sep 29 11:05:04 +0000 2023"}
# {"annotations": [], "text": "The second method, the material-based methods focuses on biodegradable materials that are often fabricated with cellular functions.", "timestamp": "Fri Sep 29 11:05:05 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "cells", "obj": "cell_type", "prob": 0.4825214147567749, "span": {"begin": 109, "end": 114}}], "text": "The most important method, that is the main focus of this paper, is tissue engineering: combining the use of cells and a biodegradable scaffold to construct a tissue [4].", "timestamp": "Fri Sep 29 11:05:06 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "hair follicle cells", "obj": "cell_type", "prob": 0.772055447101593, "span": {"begin": 15, "end": 34}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.7899121046066284, "span": {"begin": 35, "end": 40}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "adipose tissue-related stem cells", "obj": "cell_type", "prob": 0.8501670956611633, "span": {"begin": 42, "end": 75}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_type", "prob": 0.8975524306297302, "span": {"begin": 81, "end": 103}}], "text": "At the base of hair follicle cells ADSCs (adipose tissue-related stem cells) are mesenchymal stem cells found in subcutaneous tissue.", "timestamp": "Fri Sep 29 11:05:07 +0000 2023"}
# {"annotations": [{"id": ["mesh:C535608", "mim:612952"], "is_neural_normalized": false, "mention": "aging", "obj": "disease", "prob": 0.6069769859313965, "span": {"begin": 31, "end": 36}}], "text": "Controlling skin regeneration, aging, and structural deficits are significant roles of these cells [8].", "timestamp": "Fri Sep 29 11:05:08 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "skin cells", "obj": "cell_type", "prob": 0.7364093065261841, "span": {"begin": 32, "end": 42}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "dead cells", "obj": "cell_type", "prob": 0.6710264086723328, "span": {"begin": 65, "end": 75}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_line", "prob": 0.8820525407791138, "span": {"begin": 100, "end": 105}}], "text": "Proliferating and dividing into skin cells to replace damaged or dead cells are known to be done by ADSCs.", "timestamp": "Fri Sep 29 11:05:09 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:960"], "is_neural_normalized": true, "mention": "CD44 fibroblast receptors", "obj": "gene", "prob": 0.8896222114562988, "span": {"begin": 133, "end": 158}}], "text": "Additionally, they also stimulate cell replication and the healing process through an autocrine and paracrine pathway by stimulating CD44 fibroblast receptors.", "timestamp": "Fri Sep 29 11:05:11 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.8539126515388489, "span": {"begin": 23, "end": 28}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "dermal fibroblasts", "obj": "cell_type", "prob": 0.9004725813865662, "span": {"begin": 140, "end": 158}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "DF", "obj": "cell_type", "prob": 0.8132140040397644, "span": {"begin": 160, "end": 162}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "endothelial cells", "obj": "cell_type", "prob": 0.9317294359207153, "span": {"begin": 165, "end": 182}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "keratinocytes", "obj": "cell_type", "prob": 0.9074699878692627, "span": {"begin": 188, "end": 201}}], "text": "During wound recovery, ADSCs have a high capacity to migrate to wounded sites and are recruited quickly, in addition to their division into dermal fibroblasts (DF), endothelial cells, and keratinocytes.", "timestamp": "Fri Sep 29 11:05:12 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Adipose", "obj": "cell_line", "prob": 0.6209666132926941, "span": {"begin": 0, "end": 7}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Adipose-derived stem cells", "obj": "cell_type", "prob": 0.9003012776374817, "span": {"begin": 0, "end": 26}}], "text": "Adipose-derived stem cells are primarily more proliferative and have immunoregulatory properties, which means they are isolated in a less disruptive and more reproducible manner with the capability of inactivating T cells [8].", "timestamp": "Fri Sep 29 11:05:13 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.8775363564491272, "span": {"begin": 25, "end": 30}}], "text": "Compared to bone marrow, ADSCs have higher multipotency, which is actually needed more for ectodermal and endodermal tissue repair.", "timestamp": "Fri Sep 29 11:05:15 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.8757020235061646, "span": {"begin": 0, "end": 5}}], "text": "ADSCs will secrete a diverse secretome, resulting in increased cell proliferation and differentiation, migration, and enhanced cellular and microenvironment safety.", "timestamp": "Fri Sep 29 11:05:15 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.843539834022522, "span": {"begin": 108, "end": 113}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.7422757148742676, "span": {"begin": 162, "end": 167}}], "text": "A set of trophic factors that secretome correlates to cytokines, growth factors, and chemokines that enable ADSCs to function as paracrine tools rather than cell ADSCs were also discovered in subcutaneous tissue.", "timestamp": "Fri Sep 29 11:05:16 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "dermal fibroblasts", "obj": "cell_type", "prob": 0.8909965753555298, "span": {"begin": 270, "end": 288}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "keratinocytes", "obj": "cell_type", "prob": 0.8751017451286316, "span": {"begin": 290, "end": 303}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "epithelial cells", "obj": "cell_type", "prob": 0.819100558757782, "span": {"begin": 341, "end": 357}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSC", "obj": "cell_line", "prob": 0.9225901961326599, "span": {"begin": 492, "end": 496}}], "text": "This involvement plays an essential role in skin restoration and regeneration by retaining and rejuvenating skin tissue structure (even it can be as a physiological reaction to local injury) by seeding younger cells to the epidermis, which they later differentiate into dermal fibroblasts, keratinocytes, and other The tendency of different epithelial cells to secrete growth factors and extracellular matrix (ECM) proteins maintains a differentiation of rejuvenation and regeneration in the ADSC microenvironment.", "timestamp": "Fri Sep 29 11:05:17 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "ADSCs", "obj": "cell_type", "prob": 0.8925387263298035, "span": {"begin": 67, "end": 72}}, {"id": ["NCBIGene:1675"], "is_neural_normalized": true, "mention": "DFs", "obj": "gene", "prob": 0.9397551417350769, "span": {"begin": 77, "end": 80}}], "text": "Furthermore, the primary sources of extracellular matrix (ECM) are ADSCs and DFs proteins involved in skin structure and functionality.", "timestamp": "Fri Sep 29 11:05:19 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Extracellular vesicles", "obj": "cell_type", "prob": 0.4533507525920868, "span": {"begin": 0, "end": 22}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mRNAs", "obj": "RNA", "prob": 0.8394555449485779, "span": {"begin": 96, "end": 101}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "miRNAs", "obj": "RNA", "prob": 0.7080469727516174, "span": {"begin": 106, "end": 112}}], "text": "Extracellular vesicles are lipid bilayer vesicles that include several RNA organisms (including mRNAs and miRNAs), soluble (cytosolic) proteins, and transmembrane proteins in the proper and functional orientation [8].", "timestamp": "Fri Sep 29 11:05:20 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "EVs", "obj": "cell_type", "prob": 0.45434096455574036, "span": {"begin": 0, "end": 3}}], "text": "EVs are involved in various mechanisms, membrane protein, lipid recycling, immune regulation, apoptosis, angiogenesis, cellular proliferation, differentiation, and tissue engineering to modulate cell recruitment.", "timestamp": "Fri Sep 29 11:05:21 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Exosomes", "obj": "cell_type", "prob": 0.704482913017273, "span": {"begin": 0, "end": 8}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "extracellular vesicles", "obj": "cell_type", "prob": 0.621383786201477, "span": {"begin": 198, "end": 220}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "EV", "obj": "cell_type", "prob": 0.8019118905067444, "span": {"begin": 222, "end": 224}}], "text": "Exosomes, which are emitted through the fusion of the multivesicular structure with both microvesicles and the cell membrane that have been released directly from the cell membrane, are examples of extracellular vesicles (EV) [4].", "timestamp": "Fri Sep 29 11:05:22 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "EVs", "obj": "cell_type", "prob": 0.4680834710597992, "span": {"begin": 28, "end": 31}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "recipient cells", "obj": "cell_type", "prob": 0.8731259107589722, "span": {"begin": 103, "end": 118}}], "text": "The many processes in which EVs are active and the elasticity in which they may affect the activity of recipient cells allows EV, a fascinating subject, to be utilized for both therapeutic and diagnostic purposes.", "timestamp": "Fri Sep 29 11:05:23 +0000 2023"}
# {"annotations": [{"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8669655323028564, "span": {"begin": 108, "end": 117}}], "text": "EVs are implicated in tissue and organ injury reconstruction and can clarify any paracrine symptoms seen in stem cell-based therapeutic approaches.", "timestamp": "Fri Sep 29 11:05:24 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "MSCs", "obj": "cell_type", "prob": 0.8379358649253845, "span": {"begin": 0, "end": 4}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "multipotent mesenchymal stem cells", "obj": "cell_type", "prob": 0.8071603775024414, "span": {"begin": 6, "end": 40}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem cells", "obj": "cell_type", "prob": 0.6837843060493469, "span": {"begin": 69, "end": 79}}], "text": "MSCs (multipotent mesenchymal stem cells) are discovered as residual stem cells in majority adult organs, especially adipose tissue.", "timestamp": "Fri Sep 29 11:05:25 +0000 2023"}
# {"annotations": [{"id": ["CL:0008019"], "is_neural_normalized": false, "mention": "mesenchymal cell", "obj": "cell_type", "prob": 0.7104618549346924, "span": {"begin": 29, "end": 45}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal vascular fraction", "obj": "cell_type", "prob": 0.8304856419563293, "span": {"begin": 94, "end": 123}}], "text": "These cells exhibit standard mesenchymal cell properties in vitro and are segregated from the mesenchymal vascular fraction.", "timestamp": "Fri Sep 29 11:05:26 +0000 2023"}
# {"annotations": [], "text": "Extracellular vesicles have a paracrine impact on cell morphology, migration, proliferation, and differentiation.", "timestamp": "Fri Sep 29 11:05:27 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "EV", "obj": "cell_type", "prob": NaN, "span": {"begin": 27, "end": 29}}], "text": "These paracrine results of EV can be helpful in regenerative medicine.", "timestamp": "Fri Sep 29 11:05:28 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "EV", "obj": "cell_type", "prob": NaN, "span": {"begin": 0, "end": 2}}], "text": "EV may be used in regenerative therapy in various ways, like injection, combining with hydrogels, and covering scaffolds with EV utilizing fibrous tissue hydrogel.", "timestamp": "Fri Sep 29 11:05:29 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "EVs", "obj": "cell_type", "prob": 0.45650002360343933, "span": {"begin": 52, "end": 55}}], "text": "Intercellular communications are essential roles of EVs through secretome that engage in.", "timestamp": "Fri Sep 29 11:05:30 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "vesicular generating cells", "obj": "cell_type", "prob": 0.914715051651001, "span": {"begin": 78, "end": 104}}], "text": "Thus, their content and functionality can vary based on the conditions of the vesicular generating cells.", "timestamp": "Fri Sep 29 11:05:31 +0000 2023"}
# {"annotations": [{"id": ["mesh:D014947"], "is_neural_normalized": false, "mention": "wound", "obj": "disease", "prob": 0.6963114142417908, "span": {"begin": 145, "end": 150}}, {"id": ["mesh:D004820"], "is_neural_normalized": false, "mention": "Epidermolysis bullosa", "obj": "disease", "prob": 0.9999995827674866, "span": {"begin": 191, "end": 212}}, {"id": ["mesh:D012871"], "is_neural_normalized": false, "mention": "genodermatosis", "obj": "disease", "prob": 0.9999988079071045, "span": {"begin": 218, "end": 232}}, {"id": ["mesh:D012871"], "is_neural_normalized": true, "mention": "hereditary skin disease", "obj": "disease", "prob": 0.9999983310699463, "span": {"begin": 236, "end": 259}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "genes", "obj": "DNA", "prob": 0.6878743767738342, "span": {"begin": 286, "end": 291}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9941519498825073, "span": {"begin": 332, "end": 340}}], "text": "Changes in EV content in response to conditions specific to growth would play a crucial role in these cases by affecting tissue regeneration and wound repair by identifying new pathways into Epidermolysis bullosa is a genodermatosis, a hereditary skin disease that usually mutations of genes encoding extracellular matrix proteins (collagen) are the primary cause.", "timestamp": "Fri Sep 29 11:05:32 +0000 2023"}
# {"annotations": [{"id": ["mesh:D001768"], "is_neural_normalized": true, "mention": "skin blistering", "obj": "disease", "prob": 0.9997007846832275, "span": {"begin": 21, "end": 36}}], "text": "Severe and prolonged skin blistering with extreme and potentially fatal complications are examples of this disorder.", "timestamp": "Fri Sep 29 11:05:33 +0000 2023"}
# {"annotations": [{"id": ["mesh:D004820"], "is_neural_normalized": false, "mention": "epidermolysis bullosa", "obj": "disease", "prob": 0.999999463558197, "span": {"begin": 26, "end": 47}}], "text": "There is no treatment for epidermolysis bullosa at the moment.", "timestamp": "Fri Sep 29 11:05:34 +0000 2023"}
# {"annotations": [{"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "patient", "obj": "species", "prob": 0.9008225202560425, "span": {"begin": 56, "end": 63}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "renewable community", "obj": "cell_type", "prob": 0.4327138066291809, "span": {"begin": 73, "end": 92}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "pluripotent stem cells", "obj": "cell_type", "prob": 0.8970630764961243, "span": {"begin": 189, "end": 211}}, {"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "patients", "obj": "species", "prob": 0.8682632446289062, "span": {"begin": 217, "end": 225}}, {"id": ["mesh:D004820"], "is_neural_normalized": true, "mention": "epidermolysis", "obj": "disease", "prob": 0.9999935626983643, "span": {"begin": 231, "end": 244}}, {"id": ["mesh:D012871"], "is_neural_normalized": false, "mention": "skin disease", "obj": "disease", "prob": 0.9995683431625366, "span": {"begin": 264, "end": 276}}, {"id": ["mesh:D017719"], "is_neural_normalized": true, "mention": "diabetic foot ulcers", "obj": "disease", "prob": 0.9999974370002747, "span": {"begin": 280, "end": 300}}, {"id": ["mesh:C535627", "mim:140000"], "is_neural_normalized": true, "mention": "DFU", "obj": "disease", "prob": 0.9999514222145081, "span": {"begin": 312, "end": 315}}], "text": "However, enabling autologous therapies developed from a patient-specific renewable community of cells count as advantages in gene therapy and editing methods, along with the development of pluripotent stem cells from patients with epidermolysis Another example of skin disease is diabetic foot ulcers, known as (DFU), which is a significant difficulty that often results in infection or even death.", "timestamp": "Fri Sep 29 11:05:35 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal", "obj": "cell_line", "prob": 0.6129691004753113, "span": {"begin": 4, "end": 15}}, {"id": ["CL:0000134"], "is_neural_normalized": false, "mention": "mesenchymal stem cell", "obj": "cell_type", "prob": 0.8544237613677979, "span": {"begin": 4, "end": 25}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "cells", "obj": "cell_type", "prob": 0.45083385705947876, "span": {"begin": 259, "end": 264}}], "text": "The mesenchymal stem cell-based therapeutic method has shown effectiveness in wound treatment, presenting a theoretically systematic alternative by treating various microaerobic Base Material and The Interaction Damaged tissue repair entails the existence of cells capable of repairing the damaged tissue and the presence of a microenvironment that facilitates adequate tissue regeneration.", "timestamp": "Fri Sep 29 11:05:36 +0000 2023"}
# {"annotations": [], "text": "Furthermore, cells must be directed to form a structure of the suitable size, shape, and in certain situations, structural support.", "timestamp": "Fri Sep 29 11:05:37 +0000 2023"}
# {"annotations": [{"id": ["mesh:D014947"], "is_neural_normalized": true, "mention": "damaged", "obj": "disease", "prob": 0.5226606130599976, "span": {"begin": 3, "end": 10}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "healthy tissue", "obj": "cell_type", "prob": 0.5655874013900757, "span": {"begin": 106, "end": 120}}], "text": "In damaged tissue, the extracellular metric is often damaged, functionally disabled, or missing, while In healthy tissue, the ECM guides and Scaffolds are structures that include the conditions for cell retention and tissue regeneration and are used to solve this problem.", "timestamp": "Fri Sep 29 11:05:39 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:2006"], "is_neural_normalized": false, "mention": "elastin", "obj": "gene", "prob": 0.99402916431427, "span": {"begin": 64, "end": 71}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9655458331108093, "span": {"begin": 77, "end": 85}}], "text": "Scaffolds may be either natural (decellularized ECM or enhanced elastin - or collagen gels) or synthetic (synthetic hydrogels or porous polymer scaffolds) [4].", "timestamp": "Fri Sep 29 11:05:41 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "cell populations", "obj": "cell_line", "prob": 0.7009629011154175, "span": {"begin": 19, "end": 35}}], "text": "To enable suitable cell populations, artificial porous scaffolds must meet precise criteria.", "timestamp": "Fri Sep 29 11:05:42 +0000 2023"}
# {"annotations": [], "text": "A synthetic scaffold, ideally, offers biodegradable, and is gradually substituted by autologous ECM.", "timestamp": "Fri Sep 29 11:05:43 +0000 2023"}
# {"annotations": [], "text": "By providing a porous structure required, cells would be able to move or they can be seeded in the scaffold to provide an environment with a sufficient supply of nutrients [4].", "timestamp": "Fri Sep 29 11:05:44 +0000 2023"}
# {"annotations": [], "text": "Cellular components are removed from the tissue using a mixture of enzymatic, physical, and chemical therapies to reduce the possibility of immune responses against antigens and the spread of pathogens in these scaffolds.", "timestamp": "Fri Sep 29 11:05:45 +0000 2023"}
# {"annotations": [], "text": "Electrospinning is the most widely utilized technique for creating porous synthetic scaffolds since it allows for the development of structures of complicated geometry variations of fiber forms in both mixed and layered configurations.", "timestamp": "Fri Sep 29 11:05:46 +0000 2023"}
# {"annotations": [{"id": ["CHEBI:60736"], "is_neural_normalized": false, "mention": "Polycaprolactone", "obj": "drug", "prob": 0.999515175819397, "span": {"begin": 0, "end": 16}}, {"id": ["CHEBI:60736"], "is_neural_normalized": false, "mention": "PCL", "obj": "drug", "prob": 0.999746561050415, "span": {"begin": 18, "end": 21}}, {"id": ["CHEBI:53492"], "is_neural_normalized": false, "mention": "polyglycolic acid", "obj": "drug", "prob": 0.9994708895683289, "span": {"begin": 24, "end": 41}}, {"id": ["mesh:D011454"], "is_neural_normalized": false, "mention": "PGA", "obj": "drug", "prob": 0.9992311596870422, "span": {"begin": 43, "end": 46}}, {"id": ["mesh:D054813"], "is_neural_normalized": false, "mention": "polyhydroxyalkanoate", "obj": "drug", "prob": 0.9992089867591858, "span": {"begin": 49, "end": 69}}, {"id": ["CHEBI:34839"], "is_neural_normalized": true, "mention": "PHA", "obj": "drug", "prob": 0.9995379447937012, "span": {"begin": 71, "end": 74}}, {"id": ["CHEBI:53408"], "is_neural_normalized": false, "mention": "polylactic acid", "obj": "drug", "prob": 0.9994500279426575, "span": {"begin": 81, "end": 96}}, {"id": ["CHEBI:53407"], "is_neural_normalized": false, "mention": "PLA", "obj": "drug", "prob": 0.9995028376579285, "span": {"begin": 98, "end": 101}}], "text": "Polycaprolactone (PCL), polyglycolic acid (PGA), polyhydroxyalkanoate (PHA), and polylactic acid (PLA) are biodegradable polymers used in electrospinning.", "timestamp": "Fri Sep 29 11:05:48 +0000 2023"}
# {"annotations": [], "text": "Combining fiber types in complex patterns, scaffold degradability, durability, and biological activity can be modulated.", "timestamp": "Fri Sep 29 11:05:49 +0000 2023"}
# {"annotations": [{"id": ["CL:0000134"], "is_neural_normalized": false, "mention": "MSC", "obj": "cell_type", "prob": 0.7420164346694946, "span": {"begin": 0, "end": 3}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen peptide", "obj": "gene", "prob": 0.8423911333084106, "span": {"begin": 103, "end": 119}}], "text": "MSC migration, proliferation, and osteogenic differentiation are improved by coating the scaffold with collagen peptide as an example.", "timestamp": "Fri Sep 29 11:05:51 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:2162"], "is_neural_normalized": true, "mention": "fibrin", "obj": "gene", "prob": 0.9925669431686401, "span": {"begin": 150, "end": 156}}], "text": "Scaffolds may also be engineered to release proteins, peptides, or cytokines through degradation or coating fibers with a biodegradable material like fibrin or gelatin containing a combination of these bioactive molecules.", "timestamp": "Fri Sep 29 11:05:52 +0000 2023"}
# {"annotations": [], "text": "Also, because of their heavily hydrated structure, low toxicity, and proximity to the extracellular matrix, hydrogels are the most commonly used bio-inks in tissue engineering to build scaffolds.", "timestamp": "Fri Sep 29 11:05:53 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "soft tissue cell types", "obj": "cell_type", "prob": 0.7395329475402832, "span": {"begin": 88, "end": 110}}, {"id": ["NCBITaxon:9606"], "is_neural_normalized": false, "mention": "people", "obj": "species", "prob": 0.9677274227142334, "span": {"begin": 204, "end": 210}}, {"id": ["mesh:D012871"], "is_neural_normalized": false, "mention": "skin disorders", "obj": "disease", "prob": 0.9999669790267944, "span": {"begin": 226, "end": 240}}, {"id": ["mesh:D002908"], "is_neural_normalized": true, "mention": "chronic wounds", "obj": "disease", "prob": 0.9998701810836792, "span": {"begin": 249, "end": 263}}, {"id": ["mesh:D014456"], "is_neural_normalized": true, "mention": "non-healing ulcers", "obj": "disease", "prob": 0.9999680519104004, "span": {"begin": 265, "end": 283}}, {"id": ["mesh:D017719"], "is_neural_normalized": true, "mention": "diabetic ulcers", "obj": "disease", "prob": 0.9999963641166687, "span": {"begin": 289, "end": 304}}], "text": "As a result, bio-ink built with gelatin and natural polymers is compatible with various soft tissue cell types and can be combined with biological molecules such as proteins, growth factors, and     Many people suffering from skin disorders such as chronic wounds, non-healing ulcers, and diabetic ulcers need skin repair and regeneration.", "timestamp": "Fri Sep 29 11:05:55 +0000 2023"}
# {"annotations": [], "text": "Aside from the diseases listed above, the industry needed a skin rejuvenation system and regeneration for cosmetic purposes.", "timestamp": "Fri Sep 29 11:05:56 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "pluripotent stem cells", "obj": "cell_type", "prob": 0.9078628420829773, "span": {"begin": 30, "end": 52}}], "text": "The procedure used to deliver pluripotent stem cells to the desired tissue was known as reconstructive medicine.", "timestamp": "Fri Sep 29 11:05:57 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "Mesenchymal stem cells", "obj": "cell_type", "prob": 0.8844725489616394, "span": {"begin": 0, "end": 22}}], "text": "Mesenchymal stem cells are the most fascinating since, when put in the correct setting and stimulated with the proper growth factors, they could choose a pathway to differentiate into the desired tissue.", "timestamp": "Fri Sep 29 11:05:58 +0000 2023"}
# {"annotations": [], "text": "They are also very available, inexpensive, simple to extract, and reproducible.", "timestamp": "Fri Sep 29 11:05:59 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_type", "prob": 0.8947269320487976, "span": {"begin": 6, "end": 28}}], "text": "These mesenchymal stem cells are derived from bone marrow, bone, connective tissues, fats, and other tissues.", "timestamp": "Fri Sep 29 11:06:00 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.8821922540664673, "span": {"begin": 31, "end": 48}}], "text": "Fat is the ideal reservoir for mesenchymal cells that have recently been identified.", "timestamp": "Fri Sep 29 11:06:01 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9961655139923096, "span": {"begin": 9, "end": 17}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.8862928152084351, "span": {"begin": 29, "end": 40}}, {"id": ["NCBIGene:4312"], "is_neural_normalized": true, "mention": "collagenase enzymes", "obj": "gene", "prob": 0.957863450050354, "span": {"begin": 67, "end": 86}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9965909719467163, "span": {"begin": 112, "end": 120}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.8792254328727722, "span": {"begin": 132, "end": 143}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_type", "prob": 0.9137372374534607, "span": {"begin": 182, "end": 204}}], "text": "Fibrous, collagen fibers and fibroblasts On one side, by injecting collagenase enzymes into the fat, all of the collagen fibers and fibroblasts can be removed, leaving just the pure mesenchymal stem cells.", "timestamp": "Fri Sep 29 11:06:03 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "engineered", "obj": "cell_line", "prob": 0.5072718262672424, "span": {"begin": 7, "end": 17}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem cell vascular fraction", "obj": "cell_type", "prob": 0.5816009044647217, "span": {"begin": 18, "end": 45}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "SVF", "obj": "cell_line", "prob": 0.737633466720581, "span": {"begin": 47, "end": 50}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.6506407856941223, "span": {"begin": 73, "end": 90}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "inflammatory cells", "obj": "cell_type", "prob": 0.8134418725967407, "span": {"begin": 108, "end": 126}}, {"id": ["CL:0000235"], "is_neural_normalized": false, "mention": "macrophage", "obj": "cell_type", "prob": 0.8712083101272583, "span": {"begin": 135, "end": 145}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "-monocyte", "obj": "cell_type", "prob": 0.7387164235115051, "span": {"begin": 145, "end": 154}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.49137890338897705, "span": {"begin": 160, "end": 171}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal cells", "obj": "cell_type", "prob": 0.8629166483879089, "span": {"begin": 177, "end": 194}}], "text": "In the engineered stem cell vascular fraction (SVF), a pellet comprising mesenchymal cells, growth factors, inflammatory cells such as macrophage-monocyte, and fibroblasts, the mesenchymal cells are segregated from the other components through centrifugation.", "timestamp": "Fri Sep 29 11:06:05 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "mesenchymal stem cells", "obj": "cell_type", "prob": 0.7281873822212219, "span": {"begin": 8, "end": 30}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "fibroblasts", "obj": "cell_type", "prob": 0.8699223399162292, "span": {"begin": 130, "end": 141}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9821366667747498, "span": {"begin": 161, "end": 169}}], "text": "Placing mesenchymal stem cells in the target environment and supplying the required growth factors can result in the formation of fibroblasts, the production of collagen, and the reconstruction of the skin.", "timestamp": "Fri Sep 29 11:06:06 +0000 2023"}
# {"annotations": [{"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem", "obj": "cell_line", "prob": 0.5125970840454102, "span": {"begin": 26, "end": 30}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8158969879150391, "span": {"begin": 26, "end": 35}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8680161237716675, "span": {"begin": 98, "end": 107}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "stem", "obj": "cell_line", "prob": 0.48889392614364624, "span": {"begin": 158, "end": 162}}, {"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8331301212310791, "span": {"begin": 158, "end": 167}}], "text": "As previously stated, the stem cell condition is essential, as there is a risk of movement of the stem cell due to blood circulation and paracrine, which the stem cell will secrete and influence its environment.", "timestamp": "Fri Sep 29 11:06:07 +0000 2023"}
# {"annotations": [{"id": ["CL:0000034"], "is_neural_normalized": false, "mention": "stem cell", "obj": "cell_type", "prob": 0.8441869616508484, "span": {"begin": 61, "end": 70}}], "text": "As a result, the scaffold is the structure that prevents the stem cell from being flushed away by the blood supply and disrupting the environment.", "timestamp": "Fri Sep 29 11:06:08 +0000 2023"}
# {"annotations": [], "text": "The scaffold must have unique properties that prevent foreign body reactions, are not antigenic or allergic, and   do not induce infection.", "timestamp": "Fri Sep 29 11:06:09 +0000 2023"}
# {"annotations": [], "text": "It must also be affordable and readily available.", "timestamp": "Fri Sep 29 11:06:11 +0000 2023"}
# {"annotations": [], "text": "Alginate scaffolds have been used in the most recent process.", "timestamp": "Fri Sep 29 11:06:12 +0000 2023"}
# {"annotations": [{"id": ["NCBIGene:960"], "is_neural_normalized": true, "mention": "CD44 receptors", "obj": "gene", "prob": 0.9897900819778442, "span": {"begin": 122, "end": 136}}, {"id": ["CUI-less"], "is_neural_normalized": false, "mention": "skin'", "obj": "cell_type", "prob": 0.6062212586402893, "span": {"begin": 144, "end": 149}}, {"id": ["NCBIGene:1280"], "is_neural_normalized": true, "mention": "collagen", "obj": "gene", "prob": 0.9960581064224243, "span": {"begin": 175, "end": 183}}], "text": "The scaffold containing the mesenchymal and critical growth factors into the desired cell will, for example, activate the CD44 receptors on the skin's fibroblasts, increasing collagen output.", "timestamp": "Fri Sep 29 11:06:14 +0000 2023"}

# %%
# !pip install neo4j
from neo4j import GraphDatabase
import pandas as pd

host = 'neo4j+s://dataset.databases.neo4j.io'
user = 'neo4j'
password = 'password'
driver = GraphDatabase.driver(host,auth=(user, password))

def neo4j_query(query, params=None):
    with driver.session() as session:
        result = session.run(query, params)
        return pd.DataFrame([r.values() for r in result], columns=result.keys())
# Out:
# Requirement already satisfied: neo4j in /usr/local/lib/python3.10/dist-packages (5.13.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from neo4j) (2023.3.post1)

# %%
author = article_txt.split("\n")[0]
title = " ".join(article_txt.split("\n")[2:4])

neo4j_query("""
MERGE (a:Author{name:$author})
MERGE (b:Article{title:$title})
MERGE (a)-[:WROTE]->(b)
""", {'title':title, 'author':author})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
neo4j_query("""
MATCH (a:Article)
UNWIND $data as row
MERGE (s:Sentence{id:row.text_sha256})
SET s.text = row.text
MERGE (a)-[:HAS_SENTENCE]->(s)
WITH s, row.entities as entities
UNWIND entities as entity
MERGE (e:Entity{id:entity.entity_id})
ON CREATE SET e.other_ids = entity.other_ids,
              e.name = entity.entity,
              e.type = entity.entity_type
MERGE (s)-[m:MENTIONS]->(e)
ON CREATE SET m.count = 1
ON MATCH SET m.count = m.count + 1
""", {'data': parsed_entities})
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# No charts were generated by quickchart

# %%
neo4j_query("""
MATCH (e:Entity)<-[:MENTIONS]-(s:Sentence)
WHERE e.name = "autoimmune diseases"
RETURN s.text as result
""")
# Out:
#                                               result
# 0  These cells, later found to be hematopoietic s...

# %%
neo4j_query("""
MATCH (e1:Entity)<-[:MENTIONS]-()-[:MENTIONS]->(e2:Entity)
WHERE id(e1) < id(e2)
RETURN e1.name as entity1, e2.name as entity2, count(*) as cooccurrence
ORDER BY cooccurrence
DESC LIMIT 3
""")
# Out:
#                   entity1      entity2  cooccurrence
# 0                collagen  fibroblasts             6
# 1  mesenchymal stem cells     collagen             4
# 2  mesenchymal stem cells  fibroblasts             4

# %%
neo4j_query("""
MATCH (a:Author)-[:WROTE]->()-[:HAS_SENTENCE]->()-[:MENTIONS]->(e:Entity)
RETURN a.name as author, e.name as entity, count(*) as count
ORDER BY count DESC
LIMIT 5
""")
# Out:
#                 author                  entity  count
# 0  Mohammadreza Ahmadi                collagen      9
# 1  Mohammadreza Ahmadi             fibroblasts      8
# 2  Mohammadreza Ahmadi               stem cell      7
# 3  Mohammadreza Ahmadi                   ADSCs      7
# 4  Mohammadreza Ahmadi  mesenchymal stem cells      7

# %%
# !pip install transformers
# !pip install scratch

from transformers import AutoTokenizer
from zero_shot_re import RelTaggerModel, RelationExtractor
from zero_shot_re import RelTaggerModel, RelationExtractor

model = RelTaggerModel.from_pretrained("fractalego/fewrel-zero-shot")
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")
relations = ['associated', 'interacts']
extractor = RelationExtractor(model, tokenizer, relations)
# Out:
# Collecting scratch
#   Downloading scratch-1.0.0.tar.gz (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: scratch
#   Building wheel for scratch (setup.py) ... done
#   Created wheel for scratch: filename=scratch-1.0.0-py2.py3-none-any.whl size=4891 sha256=c3fc5a449ce9e88ed17b0f6cbf04a8a4dc4b37b6ca6e79ffab22145cd11b8c69
#   Stored in directory: /root/.cache/pip/wheels/3d/bf/6e/e1ae84c0715e36d2c2c808a0ef17c289866ca1e79c32ad378c
# Successfully built scratch
# Installing collected packages: scratch
# Successfully installed scratch-1.0.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-94de21eb6842> in <cell line: 5>()
#       3
#       4 from transformers import AutoTokenizer
# ----> 5 from zero_shot_re import RelTaggerModel, RelationExtractor
#       6
#       7 model = RelTaggerModel.from_pretrained("fractalego/fewrel-zero-shot")
#
# ModuleNotFoundError: No module named 'zero_shot_re'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import itertools
# Candidate sentence where there is more than a single entity present
candidates = [s for s in parsed_entities if (s.get('entities')) and (len(s['entities']) > 1)]
predicted_rels = []
for c in candidates:
  combinations = itertools.combinations([{'name':x['entity'], 'id':x['entity_id']} for x in c['entities']], 2)
  for combination in list(combinations):
    try:
      ranked_rels = extractor.rank(text=c['text'].replace(",", " "), head=combination[0]['name'], tail=combination[1]['name'])
      # Define threshold for the most probable relation
      if ranked_rels[0][1] > 0.85:
        predicted_rels.append({'head': combination[0]['id'], 'tail': combination[1]['id'], 'type':ranked_rels[0][0], 'source': c['text_sha256']})
    except:
      pass

neo4j_query("""
UNWIND $data as row
MATCH (source:Entity {id: row.head})
MATCH (target:Entity {id: row.tail})
MATCH (text:Sentence {id: row.source})
MERGE (source)-[:REL]->(r:Relation {type: row.type})-[:REL]->(target)
MERGE (text)-[:MENTIONS]->(r)
""", {'data': predicted_rels})

# %% [markdown]
# You can examine the extracted relationships between entities and the source text with the following Cypher query:

# %%
neo4j_query("""
MATCH (s:Entity)-[:REL]->(r:Relation)-[:REL]->(t:Entity), (r)<-[:MENTIONS]-(st:Sentence)
RETURN s.name as source_entity, t.name as target_entity, r.type as type, st.text as source_text
""")
# Out:
#    source_entity  ...                                        source_text
# 0  skin diseases  ...  Many people with skin diseases such as chronic...
# 1  skin diseases  ...  Many people with skin diseases such as chronic...
# 2       leukemia  ...  These cells, later found to be hematopoietic s...
# 3          ADSCs  ...  Furthermore, the primary sources of extracellu...
#
# [4 rows x 4 columns]

# %%
# mesh enrichment
neo4j_query("""
MATCH (e:Entity)
WHERE e.name = "Epidermolysis bullosa"
WITH e,
    [id in e.other_ids WHERE id contains "MESH" | split(id,":")[1]][0] as meshId
CALL apoc.load.json("https://id.nlm.nih.gov/mesh/lookup/details?descriptor=" + meshId) YIELD value
RETURN value
""")
# Out:
#                                                value
# 0  {'qualifiers': [{'resource': 'http://id.nlm.ni...
